# %% [markdown]
# <h1><center>Fist Things First in UrbanNet Lab</center></h1>
# <h3 align="right">Ruiqi LI</h3>
#
# # First and foremost, welcome you to UrbanNet Lab!
#
#
# ### Below are a few things I need to address before you start your scientific journey:
#
# ***
# -------------------------------------------------------------------------------------------------------------------------
# # Science is about exploration! revealing (hidden) universal patterns, and understanding the mechanics behind them!  We are not engineers.
#     The journey of any important discovery is never an easy straight line, instead, it might a detoured and tangled mess, but the meaning of science is about exploration and gaining insights while cutting through the messiness of reality.
#    ### So don't lose heart when you seems to be in nowhere, *read more, think more and try more!*
# ![image.png](attachment:image.png)
# <center>[The figure above is from the book Networks, A.-L. Barabasi]</center>
#
# ### Learn how to *think!* and how to *analyze!* in a scientific way. These are the most important things.
#
# # So read some papers before diving into your project, and read more papers when you are puzzled while doing your project! (Read at least 50 papers during 3 years)
#
#
# ## Be humble, learn first and critizise much later
# You need to first understand what those famous papers are really talking about, why they write stories like that and think like that, before naively concluding that those papers are crap...
# ## Keep an open and broad mind, read papers in other related fields, whose ideas and approaches might be of great benefit to you!
#     The first level of reading papers might be learning their methods and approaches (some methodological papers are focusing on such topics);
#
#     the second higher level would be the understanding of the subject, with all the help from various methods, what unrevealed patterns we may observe, what mechanics we can infer and validate, and what insights we can gain;
#
#     the third level would be learning from those authors how they think, how they conceive such studies, how they organize the paper and tell the stories.
#
#     So after reading the papers, how to do some "transfer learning" to benefit your own research is the most important.
#
# ## Keep track of newest papers and discoveries in your field.
#     This is also very important! You can (1) frequently check (or just subscribe) some related journals to see if there are some related papers, (2) sign up at ResearchGate or Mendaley or GoogleScholar and follow some related scholars and works, read new papers about your subject (you can find us at https://www.researchgate.net/profile/Ruiqi_Li16, https://www.mendeley.com/profiles/ruiqi-li7/)
# ## Make sure to have a clear understanding of important concepts and how they did the research. So read carefully! You may need to read some important papers for more than twice (and usually, when you read the paper after you did some practical researches, you may have some deeper understanding).
# #### And if your work will be built on the results or models of other papers, the best way is to reproduce their results!
#
#
# ***
# ***
#
# # Keep track of your own working record -- Weekly Report
# #### This is not really intended for evaluation, but for communication, and mainly for you to clear your mind and have some time to think about your own project. Hope that the roughly 100 reports you wrote and 50 papers you read can be eventually easily assembled to become your Thesis!!
#
# ## Combine your results with your analysis and understanding (a plain figure may not be good)
# ## You can even show some unsuccessful try out, and summarize a little bit about what you learnt. Don't lose heart when your attempts are not that successful!
#
#
#     While approaching your target, you have to try a lot. That's the most normal things in anyone's scientific career.
#
#     Below are some hints on how you force your way out:
#
# # Keep agile, and flexible! So use Jupyter Notebook!
# ## For the style of the code
#     See reference at https://github.com/gboeing/urban-data-science, https://github.com/gboeing/urban-data-science/blob/master/19-Spatial-Analysis-and-Cartography/rtree-spatial-indexing.ipynb
# ## Sign up in Github and join UrbanNet Lab!
#     Find us at https://github.com/UrbanNet-Lab. In line with the requirement of scientific journals, now the code related to the paper will need to be uploaded, and give the link at Code Availability section in the paper.
# ## Separate your data and figure drawing script
#    This is more about keeping agile and flexible, **don't make the structure of your code too complex**. Different from doing engineering works, we need to stay **adaptive and agile** and make the codes easier to be modified, which is frequently happening during the research process!
#    **Keep it more process orientated might be even better.** Make the code or functions that would be frequently used as a separate file and import it (yet still, you may need to modify it to fit to another specific task, then just paste previous code and change it accordingly)! Make it Easy and Simple!
# ## Always test your code or algorithms on some simple artificial examples
#    When you first try out any not familiar algorithms, to ensure the corectness, first think about some cases (even extreme cases) and test it aginst your code.
#
#
# ***
# ***
#
# # Things need to do first:
#     1) Read 1 book and 10-20 related papers about your subject (but do it reversely, first read papers, then the book), which is very very important to give you a big picture of what you are studying.
#
#     2) write a summary about what you learnt from those papers
#
#     3) Sign up in ResearchGate and follow some related scholars, read new papers about your subject (you can find me at https://www.researchgate.net/profile/Ruiqi_Li16)
#
#
# ## Recommendataion of books and related papers:
#     Network Science [by Albert-Laszlo Barabasi] (related papers: Emergence of scaling in random networks)
#     网络科学
#
#     Scale [by Geoffrey West]
#     (related papers: Luis M.A. Bettencourt et al. PNAS 2007, Geoffrey West et al. Nature, Science...)
#     规模
#
#     How common sense mislead us [by Duncan Watts]
#     反常识
#
#     Linked [by Albert-Laszlo Barabasi](related papers: )
#     链接
#
#     Bursts [by Albert-Laszlo Barabasi](related papers: Dirk Brockmann, et al. Nature 2006, Barabasi et al. Nature 2008)
#     爆发
#
#     Social Physics [by Alex 'Sandy' Pentland]
#     智慧社会
#
#     * Above books all have Chinese translations.
#
#     网络科学导论 [汪小帆，李翔，陈关荣]
#     复杂系统与复杂网络 [何大韧，刘宗华，汪秉宏]
#
# ## Researchers on Urban Science
# Luis M.A. Bettencourt      UChicago, USA
#
# Marc Barthelemy             CEA, France
#
# Geoffrey West                 SFI, USA
#
# Hernan Makse                 NYU, USA
#
# Cesar Hidalgo                  France
#
# H. Eugene Stanley           BU, USA
#
# Jose Lobo                         ASU, USA
#
# Hyejin Youn                      NWU, USA
#
# Christa Brelsford          Oak Ridge National Laboratory, USA
#
# Marc Keuschnigg            Sweden
#
# Michael Szell              Copenhagen
#
# Filippo Simini             UK
#
# Karen C. Seto                   Yale, USA
#
# Michael Batty                    UCL, UK
#
# Elsa Arcaute                      UCL, UK
#
# Carlo Ratti                      MIT, USA

# %% [markdown]
# ## 研究生阶段一定要把自己培养成有独立思考能力与分析能力的人
#
#
#    1、必须读足够量的英文文献，虽然这个过程一开始可能很痛苦，但这是非常必要的，因为文献阅读量少的时候，很容易产生各种困惑，比如对于自己做出来的结果到底能不能成为“结论”、有什么样的结论、可能有哪些尝试的方向就很不清楚
#
#    1.1 必须要养成追踪前沿进展和广泛阅读的习惯，自己必须对所研究的问题有所把握
#
#     然后对于最新的重要进展可以写成整理性的文章，做的好的我完全可以推荐到集智学园(campus.swarma.org)去，这样自己既能了解相关领域最新动态，又能赚稿费！
#
#    1.2 多去外面听一些讲座，或者在网上看一些相关领域大牛的视频直播之类，看看别人对于问题是如何分析和理解的
#
#
#
#    2、每周总结一下自己一周来的进展和问题，对于很多关键所在可以多花笔墨，比如一些重要指标的计算过程或者思考。我并不希望用这样的方式来所谓考核大家，但是记录是非常重要的梳理思路与交流的过程。最后交给我一个PDF文档，我会给大家提供相应的反馈，其中有些问题也会一起讨论。
#
#    2.1 在初期，这样的总结是非常必须的！
#
#     这样的总结可以包括最近做的工作的记录，对于自己的工作量、得出的结果以及相应的关键过程，另外还可以有自己对于近期研究思路的分析与思考；
#
#     另外也可以是自己对看过的某篇文章的总结，这样的总结不必事无巨细，但要能够把自己对于整个文章的大体思路、大致方法和结论有一个梳理，更进一步可以写更多自己对于这一文章的一定的评述，它可能好在哪里、哪里还有可以改进的空间、文章整体的质量如何等等。
#
#     对于看文献，在看的过程中多思考些为什么、多想想他们的关键细节是怎么处理的，很多好的文章，都会有补充材料(Supporting Information, Supplementary Materials)，都可以从PDF的链接中或文章的网页上下载。重要的好文章是值得反复读三四遍的，可能每一遍感受都会不同。
#
#    <h5 align="center"> 周报不只是为了阶段性总结目前的工作，也是为自己未来写论文和毕业论文做准备。最终希望大家3年内写的100多份总结，和自己读过的50多篇论文，能够很容易把“拼接”成自己的学位论文！</h5>
#
#
#    3、要能够从复杂的结果中观察、量化，来找出规律
#
#     很多规律未必是一眼就能看出来，这时候就需要静下心来分析，设计相应的量化指标进一步研究。这方面一则可以自己多加分析，另外在阅读文献的过程中可以多向相关的文章学习
#
#
#
#    4、代码风格
#
#    最关键的是要保持敏捷、灵活。不要把代码结构搞的太复杂、僵硬，把代码做成流程化、面向研究过程的甚至可能更好，原则是要**方便管理与修改**，代码的命名也完全可以针对某个具体过程、某张图，这样在具体需要修改时可以非常容易的找到对应代码进行修改！
#
#    另外要把运算与画图分开，因为画图可能是会需要做很多调整的，所以把需要长时间计算的结果存到相应的文件，然后画图时就只要读取结果文件就可以了。
#
#    尤其是要使用**Jupyter Notebook**，这样代码和结果都能够有效的展现在你面前，能够快速定位到要修改的位置。
#
#    另外对于经常要使用的自定义的函数，完全可以写成一个单独的文件，然后import就可以！但在具体任务上，仍然可能需要进行相应的修改，那就直接把过去的代码拷备过来进行相应修改就好！
#
#
#
#     做一般的科研是容易的，它其实就像是做大作业一样，别人有的方法、别人发现过的规律，我们换个数据集，照着别人的样子完全可以再做一遍。但是这样的研究的意义何在呢？我们获得了哪些新的认识？发现了哪些新的规律？
#    ## 科研最难的地方就在于不断摸索、探寻未知，这才是科研的本质；科研的过程也本来就是要不断突破自己、不断去想自己未曾想到、未曾想通的问题，这又如何可能会容易？

# %% [markdown]
# # Examples of Jupyter Notebook style code

# %%
import seaborn as sns
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
ax = sns.swarmplot(x=tips["total_bill"])

# %%
ax = sns.swarmplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips)

# %%
ax = sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
ax = sns.swarmplot(x="day", y="total_bill", data=tips,
               color="white", edgecolor="gray")

# %%
ax = sns.violinplot(x="day", y="total_bill", hue="smoker",
                   data=tips, palette="muted", split=True)

# %% [markdown]
# The links to examples of above figures: https://seaborn.pydata.org/generated/seaborn.swarmplot.html, http://seaborn.pydata.org/generated/seaborn.violinplot.html
#
# You can write LaTex style formulas: $e^{i\pi} + 1 = 0$ (inline one)
# Expressions on their own line are surrounded by 2 consecutive dollar symbols \\$\\$:
# $$e^{i\pi} + 1 = 0$$
#
#
# You can use backslash to generate literal characters which would otherwise have special meaning in the Markdown syntax. See for next two examples:
#
# \*literal asterisks\*
#  *literal asterisks*
#
# Use double backslash   to generate the literal dollar symbol ($).

# %% [markdown]
# ```python
# print "Hello World"
# ```
#
# ```javascript
# console.log("Hello World")
# ```

# %% [markdown]
# | This | is   |
# |------|------|
# |   a  | table sfsdaafsd|

# %% [markdown]
# Add some figures or screen shots are also quite easy, just paste it!
# ![image.png](attachment:image.png)

# %%
# coding=utf-8
import numpy as np
from sklearn import metrics

# MAPE和SMAPE需要自己实现s
def mape(y_true, y_pred):
    return np.mean(np.abs((y_pred - y_true) / y_true)) * 100

def smape(y_true, y_pred):
    return 2.0 * np.mean(np.abs(y_pred - y_true) / (np.abs(y_pred) + np.abs(y_true))) * 100

y_true = np.array([1.0, 5.0, 4.0, 3.0, 2.0, 5.0, -3.0])
y_pred = np.array([1.0, 4.5, 3.5, 5.0, 8.0, 4.5, 1.0])

# MSE
print(metrics.mean_squared_error(y_true, y_pred)) # 8.107142857142858
# RMSE
print(np.sqrt(metrics.mean_squared_error(y_true, y_pred))) # 2.847304489713536
# MAE
print(metrics.mean_absolute_error(y_true, y_pred)) # 1.9285714285714286
# MAPE
print(mape(y_true, y_pred)) # 76.07142857142858
# SMAPE
print(smape(y_true, y_pred)) # 57.76942355889724
# Out:
# 8.107142857142858
# 2.847304489713536
# 1.9285714285714286
# 76.07142857142858
# 57.76942355889724

# %% [markdown]
# ## Welcome to the fractal world!
# #### Think about the curve of $y=x^{-1}$ (or more generally $y=x^{-\gamma}$), which is also the 80-20 law (first discovered by Pareto when investigating the distribution of wealth), is it self-similar (fractal)?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

N = 4
X = np.arange(1,10**(N)+1)
X = X.astype(float)
# Y = np.zeros(1000000-1)
# for i in range(len(Y)):
#     Y[i] = X[i]**(-2)
Y = X**(-2)

plt.plot(X,Y)

SCALE = 10
ax = []
fig = plt.figure(N,  figsize=(12, 12),facecolor='white')
# for i in range(1,np.sqrt(N)+1):
#     for j in range(1,np.sqrt(N)+1):
for i in range(int(np.sqrt(N))):
    for j in range(int(np.sqrt(N))):
        delta = int( i*np.sqrt(N)+j)
#         ax = fig.add_subplot(np.sqrt(N),np.sqrt(N),delta)
#         ax.plot(X[SCALE**delta:SCALE**(delta+1)],Y[SCALE**delta:SCALE**(delta+1)])
        ax.append( fig.add_subplot(np.sqrt(N),np.sqrt(N),delta+1) )
        ax[-1].plot(X[SCALE**delta-1:SCALE**(delta+1)],Y[SCALE**delta-1:SCALE**(delta+1)])
#         print(SCALE**delta)

# %%
from numpy import exp, linspace, random

def gaussian(x, amp, cen, wid):
    return amp * exp(-(x-cen)**2 / wid)

from scipy.optimize import curve_fit

x = linspace(-10, 10, 101)
y = gaussian(x, 2.33, 0.21, 1.51) + random.normal(0, 0.2, x.size)

init_vals = [1, 0, 1]  # for [amp, cen, wid]
best_vals, covar = curve_fit(gaussian, x, y, p0=init_vals)
print('best_vals: {}'.format(best_vals))

from lmfit import Model

gmodel = Model(gaussian)
print('parameter names: {}'.format(gmodel.param_names))
print('independent variables: {}'.format(gmodel.independent_vars))
params = gmodel.make_params(cen=5, amp=200, wid=1)

x_eval = linspace(0, 10, 201)
y_eval = gmodel.eval(params, x=x_eval)

plt.plot(x, y, 'bo')
plt.plot(x_eval, y_eval, 'r')
# Out:
# best_vals: [2.37157428 0.15484586 1.53303926]
# parameter names: ['amp', 'cen', 'wid']
# independent variables: ['x']

# %%
import matplotlib.pyplot as plt
from numpy import exp, loadtxt, pi, sqrt

from lmfit import Model

#data = loadtxt('model1d_gauss.dat')
#x = data[:, 0]
#y = data[:, 1]


def gaussian(x, amp, cen, wid):
    """1-d gaussian: gaussian(x, amp, cen, wid)"""
    return (amp / (sqrt(2*pi) * wid)) * exp(-(x-cen)**2 / (2*wid**2))


gmodel = Model(gaussian)
result = gmodel.fit(y, x=x, amp=5, cen=5, wid=1)

print(result.fit_report())

plt.plot(x, y, 'bo')
plt.plot(x, result.init_fit, 'k--', label='initial fit')
plt.plot(x, result.best_fit, 'r-', label='best fit')
plt.legend(loc='best')
plt.show()
# Out:
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 50
#     # data points      = 101
#     # variables        = 3
#     chi-square         = 4.39793718
#     reduced chi-square = 0.04487691
#     Akaike info crit   = -310.532476
#     Bayesian info crit = -302.687114
# [[Variables]]
#     amp:  5.19856905 +/- 0.19510730 (3.75%) (init = 5)
#     cen:  0.19678424 +/- 0.03456653 (17.57%) (init = 5)
#     wid:  0.79761905 +/- 0.03456653 (4.33%) (init = 1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, wid) =  0.577

# %%
sf = s.split('、')
len(sf), sf
sf = [x.strip('省') for x in sf]
len(sf), sf
# Out:
# (23,
#  ['河北',
#   '山西',
#   '辽宁',
#   '吉林',
#   '黑龙江',
#   '江苏',
#   '浙江',
#   '安徽',
#   '福建',
#   '江西',
#   '山东',
#   '河南',
#   '湖北',
#   '湖南',
#   '广东',
#   '海南',
#   '四川',
#   '贵州',
#   '云南',
#   '陕西',
#   '甘肃',
#   '青海',
#   '台湾'])

# %%
x = a.split()
len(x) 
y = [i for i in x if len(i)>1 and i not in sf]
len(y), y, len(set(y))
# Out:
# (129,
#  ['安庆',
#   '滁州',
#   '合肥',
#   '马鞍山',
#   '芜湖',
#   '北京',
#   '北京',
#   '重庆',
#   '重庆',
#   '福州',
#   '泉州',
#   '厦门',
#   '漳州',
#   '东莞',
#   '佛山',
#   '广州',
#   '惠州',
#   '江门',
#   '清远',
#   '深圳',
#   '珠海',
#   '湛江',
#   '中山',
#   '贵阳',
#   '广西',
#   '北海',
#   '防城港',
#   '桂林',
#   '柳州',
#   '南宁',
#   '兰州',
#   '鄂州',
#   '黄石',
#   '武汉',
#   '襄阳',
#   '宜昌',
#   '长沙',
#   '常德',
#   '岳阳',
#   '株洲',
#   '保定',
#   '廊坊',
#   '秦皇岛',
#   '石家庄',
#   '唐山',
#   '张家口',
#   '保亭',
#   '澄迈',
#   '儋州',
#   '海口',
#   '临高',
#   '乐东',
#   '陵水',
#   '琼海',
#   '三亚',
#   '五指山',
#   '文昌',
#   '万宁',
#   '开封',
#   '洛阳',
#   '新乡',
#   '许昌',
#   '郑州',
#   '哈尔滨',
#   '常州',
#   '海门',
#   '淮安',
#   '江阴',
#   '昆山',
#   '南京',
#   '南通',
#   '苏州',
#   '无锡',
#   '徐州',
#   '盐城',
#   '镇江',
#   '长春',
#   '赣州',
#   '九江',
#   '吉安',
#   '南昌',
#   '上饶',
#   '大连',
#   '丹东',
#   '沈阳',
#   '内蒙古',
#   '呼和浩特',
#   '宁夏',
#   '银川',
#   '上海',
#   '上海',
#   '成都',
#   '德阳',
#   '达州',
#   '乐山',
#   '凉山',
#   '绵阳',
#   '眉山',
# ...
